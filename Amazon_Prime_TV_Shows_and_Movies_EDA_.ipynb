# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav04040/almabetter-codestorm-capstone-Module1/blob/main/Amazon_Prime_TV_Shows_and_Movies_EDA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EXPLORATORY DATA ANALYSIS(EDA)
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# Exploratory Data Analysis (EDA) is an important part of the data analysis process. It helps us understand the structure, characteristics, and patterns in a dataset. EDA includes summarizing, visualizing, and interpreting data using statistical and graphical methods to extract useful insights. This process allows analysts to spot trends, find anomalies, address missing values, and discover relationships between variables before moving on to more complex analytical or machine learning methods.
#
# In this project, we performed Exploratory Data Analysis on the Amazon Prime TV Shows and Movies dataset. This dataset contains information about movies and TV shows available on the Amazon Prime streaming service. Amazon Prime is one of the top digital entertainment platforms worldwide, offering a large collection of movies, TV series, documentaries, and original content across many genres and countries.
#
# The main goal of this project was to analyze the content on Amazon Prime and gather meaningful insights about content distribution, genres, release trends, ratings, production countries, and other significant factors. To achieve this, we used Python libraries like Pandas and NumPy for data manipulation and preprocessing. We also used Matplotlib and Seaborn to create useful visualizations.
#
# We started the analysis by importing the required libraries and loading the dataset into a Pandas DataFrame. We explored the data by looking at the first and last few rows, checking the dataset's dimensions, data types, and overall layout. This helped us get a basic understanding of the features available and their importance.
#
# Next, we cleaned and preprocessed the data. We identified and addressed missing values, duplicate records, and inconsistencies in the dataset to ensure its quality. We examined the unique values in different columns like type, rating, genre, country, and release year to better understand the dataset's makeup.
#
# After organizing the data, we carried out a detailed exploratory analysis using various visualization techniques. We performed univariate analysis to study individual variable distributions. Bivariate and multivariate analyses helped us explore relationships between multiple variables. We created several visualizations, including bar charts, histograms, count plots, scatter plots, heatmaps, and pair plots, to reveal patterns and trends in the dataset.
#
# These visualizations allowed us to analyze the distribution of movies versus TV shows, the most popular genres, content ratings, yearly content additions, country-specific content production, and other key aspects of the Amazon Prime catalog. The findings offer valuable insights into Amazon Prime's content strategy, audience preferences, and content diversity.
#
# Overall, this EDA project shows how data visualization and statistical analysis can change raw data into practical insights. The analysis helps us understand content trends on Amazon Prime and can assist with data-driven decision-making for content management, recommendation systems, and business growth strategies.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# What is the most popular show, whether it is a movie or a TV show, whose rating is high? What type of movie is most popular, and what are the obstacles that might affect the business growth of the Amazon Prime Video platform?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# Answer Here.
#
# With this EDA project, by analyzing this dataset, businesses, content creators, and data analysts can uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
Amazon_Prime = pd.read_csv('/content/drive/MyDrive/titles.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
Amazon_Prime
# Out:
#              id                            title   type  \
# 0       ts20945                The Three Stooges   SHOW
# 1       tm19248                      The General  MOVIE
# 2       tm82253      The Best Years of Our Lives  MOVIE
# 3       tm83884                  His Girl Friday  MOVIE
# 4       tm56584                In a Lonely Place  MOVIE
# ...         ...                              ...    ...
# 9866   tm510327                     Lily Is Here  MOVIE
# 9867  tm1079144  Jay Nog: Something from Nothing  MOVIE
# 9868   tm847725                          Chasing  MOVIE
# 9869  tm1054116                         Baikunth  MOVIE
# 9870   ts275838                 Waking Up Eighty   SHOW
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
Amazon_Prime.shape
# Out:
# (9871, 15)

# %% [markdown]
# This Dataset has 15 Columns and 9871 Rows

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Amazon_Prime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
Amazon_Prime.duplicated().sum()
# Out:
# np.int64(3)

# %% [markdown]
# There are 3 Duplicate Values

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
Amazon_Prime.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
# Visualizing the missing values
Amazon_Prime[Amazon_Prime.isnull().any(axis=1)]
# Out:
#              id                            title   type  \
# 1       tm19248                      The General  MOVIE
# 2       tm82253      The Best Years of Our Lives  MOVIE
# 3       tm83884                  His Girl Friday  MOVIE
# 4       tm56584                In a Lonely Place  MOVIE
# 5      tm160494                       Stagecoach  MOVIE
# ...         ...                              ...    ...
# 9866   tm510327                     Lily Is Here  MOVIE
# 9867  tm1079144  Jay Nog: Something from Nothing  MOVIE
# 9868   tm847725                          Chasing  MOVIE
# 9869  tm1054116                         Baikunth  MOVIE
# 9870   ts275838                 Waking Up Eighty   SHOW
#
#                                             description  release_year  \
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# 3     Hildy, the journalist former wife of newspaper...          1940
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
# This Amazon Prime Video dataset is a CSV file that contains all the data of entertainment shows, which can be TV shows or movies. Through pandas, we have imported this dataset into a pandas DataFrame that contains 9871 rows and 15 columns. The dataset contains 3 duplicate values. The description has 119 null values, which is the lowest number of null values in the dataset, and the Seasons column has the highest number of null values 8514.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
Amazon_Prime.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
# Dataset Describe
Amazon_Prime.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here
#
# The Amazon Prime Video dataset contains 15 variables, detailing the movies and series available on the platform. These variables are identifiers (id, imdb_id), content details (title, type, description, genres, production_countries) and temporal information (release_year, seasons). The dataset also contains audience and quality metrics such as imdb_score, imdb_votes, tmdb_popularity, and tmdb_score, which can be used to measure popularity and ratings of titles. In addition runtime is the length of the content and age_certification defines the correct age group of the audience. These variables allow for a comprehensive analysis of the distribution of content, popularity, ratings, genres, and viewing habits on Amazon Prime Video.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
Amazon_Prime.nunique()
# Out:
# id                      9868
# title                   9737
# type                       2
# description             9734
# release_year             110
# age_certification         11
# runtime                  207
# genres                  2028
# production_countries     497
# seasons                   32
# imdb_id                 9201
# imdb_score                86
# imdb_votes              3650
# tmdb_popularity         5325
# tmdb_score                89
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
Amazon_Prime.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
Amazon_Prime.replace(" " ,np.nan ,inplace= True)

# %%
Amazon_Prime.replace(["NaN"] ,np.nan ,inplace= True)

# %%
Amazon_Prime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %%
Amazon_Prime.shape
# Out:
# (9871, 15)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
#
# The missing numbers were replaced by NaN values.Next, I determine whether any missing values are still present. Finally, I verified each variable's datatype. With the exception of the IMDb-related part, TMDB-related section, and season, all of the runtime fields are objective or categorical data.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
Amazon_Prime['production_countries'].str.split(',').explode().value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='production_countries'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I picked a bar chart because it is ideal for comparing categorical data like production countries. It clearly shows which countries contribute the most titles to Amazon Prime, making it easy to identify leaders and laggards in content production.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# A small number of countries (e.g., USA, UK, India) dominate the content library. Other countries contribute fewer titles, suggesting regional content concentration.If Amazon is aiming for global reach, some regions may be underrepresented, indicating untapped markets.The chart highlights content diversity (or lack of it) across production countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Content Expansion Strategy: To draw in new customers, Amazon might identify underrepresented nations and areas and fund regional productions.Market positioning: Knowing which nations provide the most content can be useful for marketing initiatives (e.g., promoting Indian content in India). Partnerships: Strategic alliances with top-producing nations or cooperation with developing markets might be guided by insights. Customer satisfaction: By appealing to a variety of cultural preferences, a more varied content collection helps increase retention.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
Amazon_Prime['release_year'].value_counts().sort_index().plot(kind='line', figsize=(10,4))
# Out:
# <Axes: xlabel='release_year'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
#  I picked a line chart because it is the best way to show trends over time. Since release_year is a chronological variable, a line chart helps visualize how the number of releases has increased or decreased across years, making patterns clear at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# We can see how content production has evolved over the years.
#
# Peaks may indicate years where more investment was made in content creation.
#
# Sudden drops may point to strategic shifts, market changes, or external factors (e.g., global events like COVID-19 in 2020 affecting production). If the trend is upward in recent years, it signals growth in Amazon Prime’s content library, aligning with customer demand for fresh content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Yes,
#
# Strategic Planning = Identifying high-growth years and replicating success strategies.
#
# Content Budgeting = Understanding if continuous content production boosts platform growth.
#
# Market Positioning = Showing customers and stakeholders that the platform is expanding its catalog.
#
# Risk Management = Spotting declines in production years can help address gaps early.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
sns.scatterplot(data=Amazon_Prime, x="runtime", y="imdb_score", hue="type", alpha=0.6)
# Out:
# <Axes: xlabel='runtime', ylabel='imdb_score'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# For illustrating the link between two continuous variables (runtime and imdb_score), I chose a scatter plot. Comparing if movies and TV shows differ in runtime versus quality assessment is made easier by adding hue="type".

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# A number of films may have runtimes between 90 and 120 minutes, and the majority of TV series may have shorter episode durations. Longer runtime does not necessarily translate into higher ratings; IMDb scores seem to be independent of runtime. Extremely long runtimes or extremely high or low scores are examples of outliers that might point to unique situations, such as documentaries, limited series, or exceptionally well-liked titles. The distribution of scores for TV series and films may vary; for example, shows may have higher average ratings because of sustained viewer involvement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Indeed, content strategy aids in determining the ideal runtimes that strike a balance between high ratings and audience engagement. Production Planning: Amazon can reduce production costs without lowering ratings if content with short and medium runtime performs equally well. Recommendation System: Algorithms can use insights to recommend content that is in line with both audience tastes and critical praise.Market segmentation: Marketing teams can more effectively target various audience groups if films and television shows perform differently in terms of runtime vs ratings.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
sns.histplot(data=Amazon_Prime, x="imdb_votes", bins=30)
# Out:
# <Axes: xlabel='imdb_votes', ylabel='Count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# A histogram is the best tool for visualizing the distribution of a single continuous variable, that is why I chose it. Here, audience engagement is measured by imdb_votes, and the histogram indicates whether the majority of titles receive few votes or if a small number of titles receive a lot of interaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The distribution on the chart is probably skewed to the right, with a small number of blockbuster titles receiving very high votes while the majority of titles earn very low votes. This suggests that the majority of activity on Amazon Prime is driven by a small number of well-known games. Star content that significantly increases the platform's visibility is highlighted by outliers, or exceptionally high vote counts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Content Strategy: By identifying titles that receive a lot of votes, Amazon is able to determine what kinds of content are most popular.
#
# Marketing Impact: To increase subscriptions and engagement, promotional efforts can make use of these top-performing titles.
#
# Investment Decisions: Because the majority of titles receive less votes, Amazon is able to allocate more funds to actors, franchises, or high-engagement categories that consistently attract viewers.
#
# Recommendation System: By emphasizing material with a high level of community interaction, the vote distribution can be used to enhance tailored recommendations.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
Amazon_Prime.groupby("release_year")['imdb_score'].mean().plot(kind='line')
# Out:
# <Axes: xlabel='release_year'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose a line graph because it clearly illustrates how the quality of the content has changed over time. A line chart makes it easy to see trends, variations, or increases in audience ratings because release_year is time-based and imdb_score is continuous.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The graph indicates whether the average content quality (as measured by IMDb ratings) has increased, decreased, or stayed constant over time. Peaks in some years might be the result of outstanding releases or effective content strategy.Declines could be a sign of times when quantity rose but quality declined. It demonstrates how viewers' opinions of Amazon Prime's content have changed over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Content Strategy: Amazon can make investments in better productions to safeguard the brand's reputation if scores have been declining recently.
#
# Marketing: To draw in and keep subscribers, high-rated years and titles can be advertised.
#
# Making decisions: Assists in striking a balance between trade-offs between quantity and quality when producing material.
#
# Customer satisfaction: Maintaining consistently good ratings fosters audience loyalty and confidence.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
sns.scatterplot(data=Amazon_Prime, x="tmdb_popularity", y="imdb_score")
# Out:
# <Axes: xlabel='tmdb_popularity', ylabel='imdb_score'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The ideal method for examining the relationship between two continuous variables is a scatter plot, which is why I chose it. Here, it aids in determining if popular titles can occasionally be critically weak or whether more popularity (buzz/engagement) translates into higher quality ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Clusters may indicate that a large number of somewhat popular titles continue to have respectable IMDb ratings. Certain films may be very successful but have average or low IMDb rankings, which means that even if critics don't think highly of them, they nevertheless draw audiences.
#
# On the other hand, certain films may have high IMDb ratings but little popularity, indicating underappreciated yet critically excellent hidden gems.
#
# Overall, the chart may show weak to moderate correlation → popularity and quality don’t always move together.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Marketing Strategy: To increase engagement, Amazon might highlight hidden gems (high score, low popularity).
#
# material Investment: Amazon can strike a balance between highly acclaimed material and mass-market blockbusters if popularity doesn't always equate to great quality.
#
# Recommendation Systems: Amazon can enhance personalized suggestions by fusing popularity and quality (not only displaying what's popular, but also what's genuinely good).
#
# Customer Retention: Providing both popular and high-caliber titles guarantees that a larger audience is satisfied.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
sns.boxplot(data=Amazon_Prime, x="type", y="imdb_score")
# Out:
# <Axes: xlabel='type', ylabel='imdb_score'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Because it's ideal for comparing the distribution, dispersion, and median of IMDb scores across several categories (Movies vs. TV Shows), I chose a boxplot. It displays overall score ranges, variability, and outliers in addition to averages.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# We can determine whether movies or TV series are often rated higher by viewers.
#
# The spread displays the degree of rating consistency:
#
# There will be more variation in quality if one variety has a larger range.
#
# Another type is often more well-received if its median is higher.
#
# Outliers draw attention to notable successes or failures in every field.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Content Strategy: If TV series routinely receive higher ratings, Amazon can devote more resources to the creation of new series; if films are the main focus, this will change.
#
# Quality Control: Amazon can establish more stringent quality standards if films exhibit greater variety.
#
# Marketing: Campaigns' best-performing content types can be highlighted with the use of insights.
#
# User Retention: Subscribers are kept interested and content by providing more of the consistently higher-rated genre (Movie/Show).

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
sns.scatterplot(data=Amazon_Prime, x="runtime", y="tmdb_popularity")
# Out:
# <Axes: xlabel='runtime', ylabel='tmdb_popularity'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The greatest option for examining the relationship between two continuous variables is a scatter plot, which is why I chose it. In this instance, it enables us to determine whether audience popularity is impacted by longer or shorter runtimes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The graph probably indicates that the majority of content is grouped around typical runtimes (e.g., 90–120 minutes for films, <60 minutes for episodes).
#
# While longer runtimes do not ensure audience buzz, popularity (tmdb_popularity) does not always rise with runtime. Short and medium-length material can be quite popular.
#
# Special releases (such as epic films, prolonged series, or specialized documentaries) may be indicated by outliers (extremely long runtimes with high/low popularity).
#
# There is no discernible strong linear link, indicating that popularity is not primarily driven by runtime.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Content Strategy: Amazon can see that shorter content can be just as popular as longer content, helping reduce production costs without losing engagement.
#
# Audience Targeting: Knowing the sweet spot for runtimes can help Amazon design content formats (mini-series, standard movies, etc.) that align with what viewers actually prefer.
#
# Marketing & Recommendations: Outlier content (very long but popular titles) can be marketed as special events to attract attention.
#
# Operational Efficiency: Prevents over-investing in unnecessarily long content when runtime doesn’t directly drive popularity.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
Amazon_Prime['type'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6,6), title="Content Type Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Pie charts are the most effective way to display proportions of categorical data, which is why I chose them. This makes it simple to quickly comprehend Amazon Prime's content strategy by plainly displaying the proportional share of movies versus TV shows in the platform's inventory.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The graph indicates whether TV series are more popular than movies or the other way around. While a significant portion of TV episodes suggests a commitment in long-term audience engagement, if movies make up the majority, Amazon Prime may be concentrating more on cinema content. The range of content and the way the platform is positioning itself in relation to rivals are reflected in the balance (or imbalance) (e.g., Netflix's heavy TV show focus).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Content strategy: Assists management in determining whether investments in films and television programs need to be rebalanced in order to improve competition.
#
# Audience Retention: Knowing TV shows' share helps Amazon improve its subscriber retention tactics because they foster long-term engagement.
#
# Marketing: Amazon can utilize this information to highlight its advantages (e.g., "Largest movie library" or "Growing TV series collection").
#
# Expansion Planning: In order to meet unmet audience demand, Amazon may approve additional productions in a category that is underrepresented.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
Amazon_Prime.nlargest(20, 'tmdb_popularity')[["title",'tmdb_popularity']].set_index('title').plot(kind='barh')
# Out:
# <Axes: ylabel='title'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose a horizontal bar chart because it makes it easy to see how the top 20 titles are ranked and compared. A horizontal bar chart prevents congestion and improves readability because titles are lengthy text strings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The graph shows which particular titles are the most popular and engaging on Amazon Prime.
#
# Certain films and TV series are very well-liked and stand out as blockbusters.
#
# Additionally, it displays patterns in viewer choices by revealing whether popularity is dominated by more recent releases or older classics.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Content Investment & Acquisition: Amazon is able to determine what kinds of content—such as Hollywood blockbusters, local movies, or well-liked TV series—are worth acquiring or creating more of.
#
# Marketing Strategy: To draw in new subscribers, the top titles may be highlighted more prominently in advertisements, promos, or suggestions.
#
# Retention & Engagement: Amazon can create customized watchlists and suggest related material by examining trends in well-known games, which keeps customers interested.
#
# Competitor Benchmarking: By identifying the popular titles, Amazon is able to assess its position in relation to Netflix, Disney+, and other streaming services.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
Amazon_Prime.nlargest(20, 'imdb_score')[['title','imdb_score']].set_index('title').plot(kind='barh')
# Out:
# <Axes: ylabel='title'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Since a horizontal bar chart makes it easiest to compare long title names with their IMDb rankings, I chose it. It provides an instant idea of the most highly regarded titles and permits ranking from highest to lowest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The graph shows which movies have received the most praise from critics and viewers.
#
# Certain titles may stand out as flagship content for Amazon Prime due to their extraordinarily high IMDb scores.
#
# It may be possible to determine if audiences prefer contemporary original content, documentaries, or classics by comparing different genres and release years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Marketing Advantage: To draw in new players who appreciate quality, highly rated games might be advertised as "critically acclaimed."
#
# Content Strategy: Based on insights, Amazon may decide to increase its investments in content that is comparable to highly regarded titles (genres, formats, or artists).
#
# User Retention: Amazon can lower churn by increasing engagement and happiness by suggesting these highly regarded titles to subscribers.
#
# Brand positioning: Amazon Prime's reputation as a platform with premium content is strengthened by prioritizing quality over popularity.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
sns.histplot(data=Amazon_Prime, x="runtime", bins=40, kde=True)
# Out:
# <Axes: xlabel='runtime', ylabel='Count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose a KDE (Kernel Density Estimation) histogram because it clearly illustrates the distribution of runtimes for Amazon Prime content. The KDE curve smoothes the distribution to show natural clusters (such as common movie lengths or short-form content), while the histogram emphasizes frequency patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The graph indicates whether the majority of content is short (less than 60 minutes), regular movie length (between 90 and 120 minutes), or long (more than 150 minutes).
#
# There are probably peaks around typical runtime standards (e.g., ~90 mins for movies, ~30–60 mins for episodes/specials).
#
# Extremely extended runtimes, or outliers, may be a sign of multi-part releases, documentaries, or specials.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Content Strategy: In order to appeal to viewers who prefer quick entertainment, Amazon might think about adding more short-form content if the majority of content is centered around movie length.
#
# User Engagement: Knowing runtime distribution helps Amazon propose content based on user time preferences (e.g., “Watch in under 1 hour”).
#
# Production Planning: Whether audiences prefer full-length films or bingeable short series, insights inform choices about upcoming original productions.
#
# Marketing: You can increase click-through rates by emphasizing runtime ("Quick 30-min watch" vs. "Epic 3-hour masterpiece").

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
sns.scatterplot(data=Amazon_Prime, x="imdb_score", y="imdb_votes")
# Out:
# <Axes: xlabel='imdb_score', ylabel='imdb_votes'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The ideal method for displaying the relationship between two continuous variables, in this case imdb_score (ratings) and imdb_votes (audience engagement), is a scatter plot, which is why I chose it. It assists in identifying correlations, clusters, and outliers that are difficult to see with conventional charts (such as a bar or line).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Higher-rated material typically receives more votes, indicating that high-quality content typically has more engagement. This is probably a favorable trend.
#
# There might be a few anomalies, such as films or television programs with ordinary ratings but a lot of votes, probably because of their popularity or star power. In a similar vein, certain content may have high ratings but little votes, suggesting that they are undiscovered gems.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# material Promotion: Amazon may increase interaction by promoting underappreciated TV series and films by identifying high-rated but low-vote material.
#
# Customer Retention: Amazon may increase audience happiness and retention by promoting highly-voted, well-rated content.
#
# Strategic Investments: Future production and licensing agreements are guided by insights that determine which kinds of shows achieve both quality (scoring) and popularity (votes).
#
# Customized Suggestions: To set itself apart from rivals, Amazon can suggest hidden treasures if certain customers have a preference for them.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
sns.heatmap(Amazon_Prime[['imdb_score','imdb_votes','tmdb_popularity','tmdb_score','runtime']].corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The best method for summarizing and visualizing relationships between several numerical variables at once is a heatmap of correlations, which is why I went with it. A heatmap provides an overview of the relationships between features such as imdb_score, imdb_votes, tmdb_popularity, tmdb_score, and runtime rather than studying pairs one at a time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# There is probably a substantial positive link between IMDb Votes and TMDB Popularity, suggesting that more popular content typically receives more votes from viewers.
#
# A moderate-to-strong positive connection between the IMDb and TMDB scores is anticipated, demonstrating consistency across various rating systems.
#
# There is likely little to no relationship between runtime and popularity or ratings, suggesting that audience appreciation is not strongly influenced by length.
#
# Additionally, the graphic shows which aspects are mostly independent and which move in tandem.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(Amazon_Prime[['imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score']], diag_kind="kde")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I selected a pairplot because it enables us to see relationships between several variables at once. It displays both:
#
# Scatterplots of two variables (imdb_score vs. imdb_votes, for example)
#
# Individual variable distributions (KDE plots) on the diagonal
#
# This makes it simple to identify outliers, correlations, and clusters in a single view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# TMDB vs. IMDb Votes Popularity: There is probably a substantial positive correlation between popularity and audience votes. There is a moderate to high positive link between the IMDb and TMDB scores, which is consistent across rating systems. IMDb/TMDB Scores vs. Votes/Popularity: Popularity doesn't always translate into higher ratings because scores have a weaker association with popularity. Distributions (KDE plots): tmdb_popularity has a skew, with a few titles dominating popularity while the majority stay low, while imdb_score clusters around mid-to-high values (many shows rated average to good).

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.
#
# I've previously performed EDA on the Amazon Prime dataset, so I can offer the customer this succinct but business-focused suggestion:
#
# Based on insights from the dataset, Amazon Prime should concentrate on audience targeting, platform optimization, and content strategy in order to increase subscriptions and engagement.
#
# 1. Content Strategy: What to Create and Purchase Invest more in popular and high-vote categories. Pairplots and scatterplots revealed a substantial correlation between IMDb votes and TMDB popularity. This indicates that viewership is influenced by audience interaction rather than just ratings.
# Strike a balance between mass-appeal and critically acclaimed content: high-popularity titles generate volume, while high IMDb/TMDB scores draw quality-conscious viewers. Both are essential.
#
# Find gaps: Certain material categories or genres (such as TV series versus movies) might be underrepresented. Filling in these gaps can draw in new viewers.
#
# 2. Marketing & Audience Targeting
# Promote popular and well-rated titles; they are "safe bets" for advertising efforts.
#
# Profit from popular but underperforming content: popular but low-rated titles might be rebranded as "guilty pleasure" or reimagined as spin-offs.
#
# Localized marketing: Make use of production nations to advertise local content in the corresponding regions.
#
# 3. Optimization of Platforms
# Recommendation Engine: Enhance algorithms by giving titles with strong engagement (popularity, votes) more weight than just ratings.
#
# Runtime insights: Audience preferences for particular durations are shown via histogram analysis of runtimes. Optimize library suggestions according to viewing preferences (longer runtime content for binge-watchers, shorter runtime shows for casual viewers).
#
# Certification (Age Rating) Mix: Make sure that all demographics are covered with a mix of adult, teen, and family-friendly content.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# We completed these EDAs as part of our project. In addition to strengthening our critical thinking abilities, this initiative aids in the extraction of insightful patterns from a given dataset. We were able to identify correlations between various variables by examining the plots, graphs, and charts.
#
# We used a variety of data visualizations, including bar graphs, box plots, scatter plots, histograms, etc., in the subsequent EDA project. We were able to observe the association between continuous and categorical variables with the aid of bar graphs. We were able to identify outliers thanks to box plots. We were able to comprehend the link between two continuous variables with the aid of scatter plots. We were able to comprehend the distribution of continuous variables thanks to the histogram.
#
# In conclusion, the company will benefit from all of the knowledge we have acquired thus far.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
